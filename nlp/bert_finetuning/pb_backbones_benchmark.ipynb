# %% [markdown]
# # PB Backbones Benchmark (BERT/RoBERTa/SciBERT)
#
# Este notebook lanza el benchmark implementado en `pb_backbones_benchmark.py`.
# Genera baseline lexico, baseline TF-IDF y comparativa de backbones con regla multilabel `threshold + delta`.

# %%
cmd = (
    "./.venv/bin/python nlp/bert_finetuning/pb_backbones_benchmark.py "
    "--models bert-base-uncased,roberta-base,allenai/scibert_scivocab_uncased "
    "--batch-size 24 --max-length 256 --fallback-top1"
)
print(cmd)

# %%
import subprocess

subprocess.run(cmd, shell=True, check=True)
